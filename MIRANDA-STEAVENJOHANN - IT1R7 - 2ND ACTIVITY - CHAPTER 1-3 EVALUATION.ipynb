# %%
print("i. Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters")
print('''\n\t-In chapter 1 in the time-frame 8:00 - 30:35, I learned the characteristics of a data structure. It should contain
      the correctness of data structure implementation, the execution time of operations must be small as possible and the memory
      usage of data structure should be as little as possible. In execution time there are 3 cases: Worst case, Average case and
      the best case. In the worst case scenario, data structure operation takes the maximum time it can take to execute. In average
      case scenario the execution time of data structure operation is average, meaning it doesn’t take the maximum time and also it
      doesn’t take the least time of execution. In the best case scenario, the execution time is the least possible execution time
      of an operation of a data structure.
      \tIn studying Data Structures and Algorithm, we can learn how to organize data in a data structure in such way that the required
      data can be searched faster and server won’t fail if there are multiple requests. I learned what Algorithm is, the characteristics
      of algorithm and how write it. Applications of Data Structures and Algorithms are the following: Search, Sort, Insert, Update & Delete.''')
print("\nii. Discuss your learnings on Chapter 1  time-frame 35:00 - end. Minimum of 200 characters")
print('''\n\t-In the time-frame 30:35-end of chapter 1, I acquired a knowledge in designing an algorithm and how to make an alternative
      to make it short and straight to the point. It makes it easy for the analyst or programmer to analyze the algorithm without the
      unwanted definitions. An algorithm's efficiency can be analyzed in two stages. First is the Priori Analysis, which is a theoretical
      analysis of an algorithm. The algorithm's effieciency is measured by assuming that all other factors have no effect on the implementation.
      Second is the Posterior Analysis, an empirical analysis of an algorithm. In this stage, the algorithm is implemented using programming
      language and executed on a computer machine. Running time and space requirement are collected. The algorithm complexity has 2 main factors,
      the Time Factor and the Space Factor. Time is measured by counting the number of key operations and space is measured by counting the maximum
      space required by the algorithm. The complexity of an algorithm f(n) gives the running time and/or the storage space required by the
      algorithm in terms of n as the size of input data. Space complexity of an algorithm represents the amount of memory space required by the
      algorithm in it s life cycle.The space required by an algorithm is equal to the sum of the following two components, the fixed part and the
      variable part. A fixed part is a space required to store certain data and variables, that are independent of the size of the problem and A
      variable part is a space required by variables , whose size depends on the size of the problem. Time complexity of an algorithm represents
      the amount of time required by the algorithm to run to completion. And lastly we learned to install python or pycharm on Local Environment.''')
print("\niii. Discuss your learnings on Chapter 2  time-frame 5:00 - 9:00. Minimum of 200 characters")
print('''\n\t-In the time-frame 5:00-9:00 of Chapter 2, I learned the two types of Data types, the Built-in Data Type and the Derived Data Type
      In built-in data types those data types for which a language has built-in support are known as Builtin Data types. Most languages provide
      built-in data types such as integers, boolean, floating, character, and strings. In the Derived Data type those data types which are
      implementation-independent as they can be implemented in one or the other way are known as derived data types. These data types are normally
      built by the combination of primary or built-in data types and associated operations on them. Example of derived data types are the following:
      List, Array, Stack, & Queue. There are basic operations that process the data in the data structure. These operations are traversing, searching,
      insertion, updating, deletion, sorting, & merging.''')
print("\niv. Discuss your learnings on Chapter 3  time-frame 3:00 - 18:00. Minimum of 200 characters")
print('''\n\t-In Chapter, I learned about arrays. Arrays can be declared in various ways in different languages. An array has type, name, size, and the
      elements. Each element can be accessed through its index and index starts with 0. So the first element of an array has a index number 0. There
      are five basic operations we can do in an array. First is traversing which is printing all the array elements one by one. Second is Insertion
      which you add an element at the given index. Third is Deletion which you can delete an element at the given index. Forth is Search where you
      can search an element using the given index or value. And fifth is Update where you can update an element at the given index. In order create
      an array we need to import first the array module to the python program.''')
from array import *
print("\nv. Create your first array project.")
any_array = array('i', [11,22,33,44,55,66,77,88,99])
for x in any_array:
    print(x)
# Out:
# i. Discuss your learnings on Chapter 1  time-frame 8:00 - 30:35. Minimum of 200 characters
#
# 	-In chapter 1 in the time-frame 8:00 - 30:35, I learned the characteristics of a data structure. It should contain
#       the correctness of data structure implementation, the execution time of operations must be small as possible and the memory
#       usage of data structure should be as little as possible. In execution time there are 3 cases: Worst case, Average case and
#       the best case. In the worst case scenario, data structure operation takes the maximum time it can take to execute. In average
#       case scenario the execution time of data structure operation is average, meaning it doesn’t take the maximum time and also it
#       doesn’t take the least time of execution. In the best case scenario, the execution time is the least possible execution time
#       of an operation of a data structure.
# ...
